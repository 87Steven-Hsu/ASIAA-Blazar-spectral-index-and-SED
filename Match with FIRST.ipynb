# %%
import pandas as pd
import numpy as np

Xmatch = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/Xmatch_result_csv.csv') # # = 37671
FIRST = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/FIRST_csv.csv')  # # = 8499

##please add your destination path to save .csv file
SAVEpath = '/Users/87steven/Documents/ASIAA/Blazar SED code and data/FIRST match'   

def ClearData():
    data = {'Name': [],
    'RA': [],
    'DEC': [],
    'z': [], 
    'Rmag': [],
    'class': [],
    'flux_ratio': [],
    'flux_143': [], 
    'flux_xray': [],
    'flux_gamma': [],
    'Spec_index': [], 
    'flux_ALMA': [], 
    'errflux': [], 
    'band': [],
    'freq': [],
    'date': [],
    'Fpeak': [],
    'Fint': [],
    'rms_error': [] }
    return data

# %%
aa = [ ]
for i, Dataname in enumerate(set(Xmatch.name[0:len(Xmatch.RA_hh)-1])): # enumerate(set(Xmatch.name[0:len(Xmatch.RA_hh)-1]))
    # set: find every name
    # enumerate: add index and list out the name
    
    print('i = ',i, ' ,source name: ', Dataname)    
    df = ClearData()
    
    RAX_hh = Xmatch['RA_hh'][Xmatch['name'] == Dataname].values[0] # RA_hh which name is consist with "Dataname", than extract it value (.values[0])
    RAX_mm = Xmatch['RA_mm'][Xmatch['name'] == Dataname].values[0]
    RAX_ss = Xmatch['RA_ss'][Xmatch['name'] == Dataname].values[0]
    DECX_dd = Xmatch['DEC_dd'][Xmatch['name'] == Dataname].values[0]
    DECX_mm = Xmatch['DEC_mm'][Xmatch['name'] == Dataname].values[0]
    DECX_ss = Xmatch['DEC_ss'][Xmatch['name'] == Dataname].values[0]
    
    # combine Xmatch coordinates into a string array
    RA_X  = f'{RAX_hh} {RAX_mm} {RAX_ss}' # sort RA in to a string array (f'')
    DEC_X = f'{DECX_dd} {DECX_mm} {DECX_ss}' # sort RA in to a string array
    
    writeXmatch = True
    for j in range(2, len(FIRST.RA_hh)-1): #range(2, 8): # range(2, len(FIRST.RA_hh)-1): *** MUST start from 2***
        
        RA_F  = f'{FIRST.RA_hh[j]} {FIRST.RA_mm[j]} {float(FIRST.RA_ss[j])}'
        DEC_F = f'{FIRST.DEC_dd[j]} {FIRST.DEC_mm[j]} {float(FIRST.DEC_ss[j])}'

        if (RA_X == RA_F):
            
            if writeXmatch: # if true
                
                ### in order to find the index of the same name
                Index = Xmatch[Xmatch['name'] == Dataname].index.tolist() # convert the index into a list 

                for x in Index: 
                    
                    df['Name'].append(Xmatch.name[x])
                    df['RA'].append(Xmatch.RA[x])
                    df['DEC'].append(Xmatch.DEC[x])
                    df['z'].append(Xmatch.z[x])
                    df['Rmag'].append(Xmatch.Rmag[x])
                    df['class'].append(Xmatch.Class[x])
                    df['band'].append(Xmatch.band[x])
                    df['freq'].append(Xmatch.freq[x])
                    df['date'].append(Xmatch.date[x])
                    df['flux_ratio'].append(Xmatch.flux_ratio[x])
                    df['flux_143'].append(Xmatch.flux_143[x])
                    df['flux_xray'].append(Xmatch.flux_xray[x])
                    df['flux_gamma'].append(Xmatch.flux_gamma[x])
                    df['Spec_index'].append(Xmatch.Spec_index[x]) 
                    df['flux_ALMA'].append(Xmatch.flux_ALMA[x])
                    df['errflux'].append(Xmatch.errflux[x])   
                    
                writeXmatch = False
                
            if not np.isnan(float(FIRST.Fpeak[j])): # if Ftot is not NaN
               
                #print('have FIRST data')
                df['Fpeak'].append(float(FIRST.Fpeak[j]))
                df['Fint'].append(float(FIRST.Fint[j]))
                df['rms_error'].append(float(FIRST.rms_error[j]))

                #print('FIRST size = ', len(df['Ftot']))
                
            else:
                
                #print('no FIRST data, source name:', Dataname)
                df['Fpeak'].append(np.nan)
                df['Fint'].append(np.nan)
                df['rms_error'].append(np.nan)
                
        else:
            
            if writeXmatch: # if true
                
                ### in order to find the index of the same name
                Index = Xmatch[Xmatch['name'] == Dataname].index.tolist() # convert the index into a list 

                for x in Index: 
                    
                    df['Name'].append(Xmatch.name[x])
                    df['RA'].append(Xmatch.RA[x])
                    df['DEC'].append(Xmatch.DEC[x])
                    df['z'].append(Xmatch.z[x])
                    df['Rmag'].append(Xmatch.Rmag[x])
                    df['class'].append(Xmatch.Class[x])
                    df['band'].append(Xmatch.band[x])
                    df['freq'].append(Xmatch.freq[x])
                    df['date'].append(Xmatch.date[x])
                    df['flux_ratio'].append(Xmatch.flux_ratio[x])
                    df['flux_143'].append(Xmatch.flux_143[x])
                    df['flux_xray'].append(Xmatch.flux_xray[x])
                    df['flux_gamma'].append(Xmatch.flux_gamma[x])
                    df['Spec_index'].append(Xmatch.Spec_index[x]) 
                    df['flux_ALMA'].append(Xmatch.flux_ALMA[x])
                    df['errflux'].append(Xmatch.errflux[x])   

                writeXmatch = False
            
    len_Xmatch = len(df['Name'])
    len_FIRST  = len(df['Fpeak'])
    
    print('len_Xmatch = ', len_Xmatch, ' len_FIRST = ', len_FIRST)
    
    # Xmatch data number > FIRST data number
    if len_Xmatch > len_FIRST:
        
        difflen = len_Xmatch - len_FIRST
        
        for ii in range(difflen):
            
                df['Fpeak'].append(np.nan)
                df['Fint'].append(np.nan)
                df['rms_error'].append(np.nan)

    # FIRST data number > Xmatch data number
    elif len_Xmatch < len_FIRST:
        
        difflen = abs(len_Xmatch - len_FIRST)
        
        for ii in range(difflen):
            
            df['Name'].append(np.nan)
            df['RA'].append(np.nan)
            df['DEC'].append(np.nan)
            df['z'].append(np.nan)
            df['Rmag'].append(np.nan)
            df['class'].append(np.nan)
            df['band'].append(np.nan)
            df['freq'].append(np.nan)
            df['date'].append(np.nan)
            df['flux_ratio'].append(np.nan)
            df['flux_143'].append(np.nan)
            df['flux_xray'].append(np.nan)
            df['flux_gamma'].append(np.nan)
            df['Spec_index'].append(np.nan)
            df['flux_ALMA'].append(np.nan)
            df['errflux'].append(np.nan)
            
    # find no FIRST data
    if (len_FIRST == 0):
        
        aa.append(Dataname)
            
    #print(pd.DataFrame(df))
    
    CSVfile = f'{SAVEpath}/{Dataname}.csv'    
    dff = pd.DataFrame(df)      
    dff.to_csv(CSVfile, index = False)
    
    print('================================================EOF================================================')
# Out:
# i =  0  ,source name:  J0303-2407
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  1  ,source name:  J0406+0637
# len_Xmatch =  4  len_FIRST =  0
# ================================================EOF================================================
# i =  2  ,source name:  J1309-3948
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  3  ,source name:  J2030-3039
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  4  ,source name:  J1703-6212
# len_Xmatch =  14  len_FIRST =  0
# ================================================EOF================================================
# i =  5  ,source name:  J0952-2453
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  6  ,source name:  J1106+2812
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  7  ,source name:  J0229-7847
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  8  ,source name:  J1610-3958
# len_Xmatch =  57  len_FIRST =  0
# ================================================EOF================================================
# i =  9  ,source name:  J1623+0741
# len_Xmatch =  3  len_FIRST =  4
# ================================================EOF================================================
# i =  10  ,source name:  J2035+1056
# len_Xmatch =  15  len_FIRST =  0
# ================================================EOF================================================
# i =  11  ,source name:  J2218-0335
# len_Xmatch =  3  len_FIRST =  7
# ================================================EOF================================================
# i =  12  ,source name:  J1350+3034
# len_Xmatch =  2  len_FIRST =  2
# ================================================EOF================================================
# i =  13  ,source name:  J0441-2952
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  14  ,source name:  J2202-2335
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  15  ,source name:  J1033+0711
# len_Xmatch =  1  len_FIRST =  2
# ================================================EOF================================================
# i =  16  ,source name:  J1145-6954
# len_Xmatch =  29  len_FIRST =  0
# ================================================EOF================================================
# i =  17  ,source name:  J1832+1357
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  18  ,source name:  J1300-3253
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  19  ,source name:  J1419+3821
# len_Xmatch =  20  len_FIRST =  1
# ================================================EOF================================================
# i =  20  ,source name:  J0112+2244
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  21  ,source name:  J0400+0550
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  22  ,source name:  J0741-4709
# len_Xmatch =  4  len_FIRST =  0
# ================================================EOF================================================
# i =  23  ,source name:  J0029+0554
# len_Xmatch =  4  len_FIRST =  3
# ================================================EOF================================================
# i =  24  ,source name:  J1410+0731
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  25  ,source name:  J0603+1742
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  26  ,source name:  J2253+1608
# len_Xmatch =  509  len_FIRST =  0
# ================================================EOF================================================
# i =  27  ,source name:  J2003-3251
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  28  ,source name:  J1925+2106
# len_Xmatch =  10  len_FIRST =  0
# ================================================EOF================================================
# i =  29  ,source name:  J0950+0615
# len_Xmatch =  3  len_FIRST =  1
# ================================================EOF================================================
# i =  30  ,source name:  J1427-3305
# len_Xmatch =  11  len_FIRST =  0
# ================================================EOF================================================
# i =  31  ,source name:  J1749-6258
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  32  ,source name:  J0138-2254
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  33  ,source name:  J2023-3655
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  34  ,source name:  J0448-2109
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  35  ,source name:  J1756+1553
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  36  ,source name:  J2257+0743
# len_Xmatch =  19  len_FIRST =  1
# ================================================EOF================================================
# i =  37  ,source name:  J1728+3838
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  38  ,source name:  J1722+2815
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  39  ,source name:  J0441-4313
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  40  ,source name:  J0138-0540
# len_Xmatch =  3  len_FIRST =  3
# ================================================EOF================================================
# i =  41  ,source name:  J2110-1020
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  42  ,source name:  J2004-6347
# len_Xmatch =  5  len_FIRST =  0
# ================================================EOF================================================
# i =  43  ,source name:  J1024-3234
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  44  ,source name:  J1840-7709
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  45  ,source name:  J1130+3815
# len_Xmatch =  2  len_FIRST =  2
# ================================================EOF================================================
# i =  46  ,source name:  J2158-3013
# len_Xmatch =  4  len_FIRST =  0
# ================================================EOF================================================
# i =  47  ,source name:  J1209-4016
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  48  ,source name:  J2212+2355
# len_Xmatch =  8  len_FIRST =  0
# ================================================EOF================================================
# i =  49  ,source name:  J1331-2639
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  50  ,source name:  J0013-1513
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  51  ,source name:  J0942-0759
# len_Xmatch =  14  len_FIRST =  0
# ================================================EOF================================================
# i =  52  ,source name:  J1539+2744
# len_Xmatch =  1  len_FIRST =  1
# ================================================EOF================================================
# i =  53  ,source name:  J0448-2626
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  54  ,source name:  J2335-0131
# len_Xmatch =  14  len_FIRST =  2
# ================================================EOF================================================
# i =  55  ,source name:  J0932-3405
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  56  ,source name:  J2007+4029
# len_Xmatch =  8  len_FIRST =  0
# ================================================EOF================================================
# i =  57  ,source name:  J0317-2803
# len_Xmatch =  11  len_FIRST =  0
# ================================================EOF================================================
# i =  58  ,source name:  J2307+1450
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  59  ,source name:  J2119-1106
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  60  ,source name:  J0007-6113
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  61  ,source name:  J0006-0623
# len_Xmatch =  756  len_FIRST =  3
# ================================================EOF================================================
# i =  62  ,source name:  J1415+1320
# len_Xmatch =  14  len_FIRST =  2
# ================================================EOF================================================
# i =  63  ,source name:  J1058-3024
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  64  ,source name:  J2108-6637
# len_Xmatch =  6  len_FIRST =  0
# ================================================EOF================================================
# i =  65  ,source name:  J1453-2522
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  66  ,source name:  J2347-4946
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  67  ,source name:  J0051-4226
# len_Xmatch =  14  len_FIRST =  0
# ================================================EOF================================================
# i =  68  ,source name:  J2025-2845
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  69  ,source name:  J0050-0929
# len_Xmatch =  7  len_FIRST =  6
# ================================================EOF================================================
# i =  70  ,source name:  J0113+1324
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  71  ,source name:  J1834-5856
# len_Xmatch =  10  len_FIRST =  0
# ================================================EOF================================================
# i =  72  ,source name:  J1902+3159
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  73  ,source name:  J2147+0929
# len_Xmatch =  8  len_FIRST =  3
# ================================================EOF================================================
# i =  74  ,source name:  J0432-5109
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  75  ,source name:  J0658-5840
# len_Xmatch =  10  len_FIRST =  0
# ================================================EOF================================================
# i =  76  ,source name:  J1012-4259
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  77  ,source name:  J0137-2430
# len_Xmatch =  24  len_FIRST =  0
# ================================================EOF================================================
# i =  78  ,source name:  J1340-0137
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  79  ,source name:  J0205+1444
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  80  ,source name:  J2108-2911
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  81  ,source name:  J1028-0236
# len_Xmatch =  10  len_FIRST =  1
# ================================================EOF================================================
# i =  82  ,source name:  J0547-6728
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  83  ,source name:  J0659-2745
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  84  ,source name:  J1026-8543
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  85  ,source name:  J0311-7651
# len_Xmatch =  5  len_FIRST =  0
# ================================================EOF================================================
# i =  86  ,source name:  J2316-3349
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  87  ,source name:  J2322+1843
# len_Xmatch =  4  len_FIRST =  0
# ================================================EOF================================================
# i =  88  ,source name:  J1516+0015
# len_Xmatch =  18  len_FIRST =  2
# ================================================EOF================================================
# i =  89  ,source name:  J1556-7914
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  90  ,source name:  J0752+3730
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  91  ,source name:  J1301-3226
# len_Xmatch =  5  len_FIRST =  0
# ================================================EOF================================================
# i =  92  ,source name:  J0039-1111
# len_Xmatch =  1  len_FIRST =  1
# ================================================EOF================================================
# i =  93  ,source name:  J2330-4539
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  94  ,source name:  J0817-0933
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  95  ,source name:  J2250-2806
# len_Xmatch =  4  len_FIRST =  0
# ================================================EOF================================================
# i =  96  ,source name:  J1248-0632
# len_Xmatch =  6  len_FIRST =  2
# ================================================EOF================================================
# i =  97  ,source name:  J1451-0127
# len_Xmatch =  2  len_FIRST =  3
# ================================================EOF================================================
# i =  98  ,source name:  J0349-2102
# len_Xmatch =  5  len_FIRST =  0
# ================================================EOF================================================
# i =  99  ,source name:  J0237+2848
# len_Xmatch =  463  len_FIRST =  0
# ================================================EOF================================================
# i =  100  ,source name:  J0224+0659
# len_Xmatch =  93  len_FIRST =  6
# ================================================EOF================================================
# i =  101  ,source name:  J1815-7001
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  102  ,source name:  J1726+3213
# len_Xmatch =  2  len_FIRST =  2
# ================================================EOF================================================
# i =  103  ,source name:  J2230-3942
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  104  ,source name:  J0457+0645
# len_Xmatch =  9  len_FIRST =  0
# ================================================EOF================================================
# i =  105  ,source name:  J0411-5149
# len_Xmatch =  17  len_FIRST =  0
# ================================================EOF================================================
# i =  106  ,source name:  J1652+3902
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  107  ,source name:  J1354-1041
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  108  ,source name:  J1256-1146
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  109  ,source name:  J0434-4355
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  110  ,source name:  J1316-3025
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  111  ,source name:  J0056+1625
# len_Xmatch =  6  len_FIRST =  0
# ================================================EOF================================================
# i =  112  ,source name:  J2311+3425
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  113  ,source name:  J2323-0317
# len_Xmatch =  30  len_FIRST =  1
# ================================================EOF================================================
# i =  114  ,source name:  J0550-5732
# len_Xmatch =  39  len_FIRST =  0
# ================================================EOF================================================
# i =  115  ,source name:  J1930-6056
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  116  ,source name:  J2248+3718
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  117  ,source name:  J0115-2804
# len_Xmatch =  11  len_FIRST =  0
# ================================================EOF================================================
# i =  118  ,source name:  J0812-1810
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  119  ,source name:  J1015+0109
# len_Xmatch =  1  len_FIRST =  2
# ================================================EOF================================================
# i =  120  ,source name:  J1227-4436
# len_Xmatch =  8  len_FIRST =  0
# ================================================EOF================================================
# i =  121  ,source name:  J1510-0543
# len_Xmatch =  5  len_FIRST =  2
# ================================================EOF================================================
# i =  122  ,source name:  J1145+0455
# len_Xmatch =  3  len_FIRST =  1
# ================================================EOF================================================
# i =  123  ,source name:  J0437-1844
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  124  ,source name:  J1147+2635
# len_Xmatch =  2  len_FIRST =  2
# ================================================EOF================================================
# i =  125  ,source name:  J1246-2547
# len_Xmatch =  17  len_FIRST =  0
# ================================================EOF================================================
# i =  126  ,source name:  J1813+2952
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  127  ,source name:  J1555+1111
# len_Xmatch =  9  len_FIRST =  4
# ================================================EOF================================================
# i =  128  ,source name:  J0609-1542
# len_Xmatch =  32  len_FIRST =  0
# ================================================EOF================================================
# i =  129  ,source name:  J1130-1449
# len_Xmatch =  22  len_FIRST =  0
# ================================================EOF================================================
# i =  130  ,source name:  J2151-2742
# len_Xmatch =  6  len_FIRST =  0
# ================================================EOF================================================
# i =  131  ,source name:  J1224+2122
# len_Xmatch =  29  len_FIRST =  3
# ================================================EOF================================================
# i =  132  ,source name:  J1238+0723
# len_Xmatch =  10  len_FIRST =  1
# ================================================EOF================================================
# i =  133  ,source name:  J0811+0146
# len_Xmatch =  9  len_FIRST =  0
# ================================================EOF================================================
# i =  134  ,source name:  J0600-3937
# len_Xmatch =  5  len_FIRST =  0
# ================================================EOF================================================
# i =  135  ,source name:  J1023+3948
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  136  ,source name:  J0439-4522
# len_Xmatch =  26  len_FIRST =  0
# ================================================EOF================================================
# i =  137  ,source name:  J0842+1835
# len_Xmatch =  6  len_FIRST =  2
# ================================================EOF================================================
# i =  138  ,source name:  J2121+1901
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  139  ,source name:  J1045+0624
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  140  ,source name:  J0141-0928
# len_Xmatch =  30  len_FIRST =  4
# ================================================EOF================================================
# i =  141  ,source name:  J0836-2016
# len_Xmatch =  19  len_FIRST =  0
# ================================================EOF================================================
# i =  142  ,source name:  J0059+0006
# len_Xmatch =  3  len_FIRST =  3
# ================================================EOF================================================
# i =  143  ,source name:  J2358+3922
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  144  ,source name:  J1416-2131
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  145  ,source name:  J0359-2615
# len_Xmatch =  4  len_FIRST =  0
# ================================================EOF================================================
# i =  146  ,source name:  J0847-2337
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  147  ,source name:  J0133-5200
# len_Xmatch =  11  len_FIRST =  0
# ================================================EOF================================================
# i =  148  ,source name:  J1202-0528
# len_Xmatch =  1  len_FIRST =  1
# ================================================EOF================================================
# i =  149  ,source name:  J1743+1935
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  150  ,source name:  J1736+0631
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  151  ,source name:  J0933-0819
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  152  ,source name:  J1319-1217
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  153  ,source name:  J0610-2301
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  154  ,source name:  J2115-1416
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  155  ,source name:  J1029-1852
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  156  ,source name:  J0431+1731
# len_Xmatch =  25  len_FIRST =  0
# ================================================EOF================================================
# i =  157  ,source name:  J2345-1555
# len_Xmatch =  19  len_FIRST =  0
# ================================================EOF================================================
# i =  158  ,source name:  J1550+1120
# len_Xmatch =  1  len_FIRST =  5
# ================================================EOF================================================
# i =  159  ,source name:  J0231-4746
# len_Xmatch =  23  len_FIRST =  0
# ================================================EOF================================================
# i =  160  ,source name:  J1445-1629
# len_Xmatch =  5  len_FIRST =  0
# ================================================EOF================================================
# i =  161  ,source name:  J0850-1213
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  162  ,source name:  J2018-1109
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  163  ,source name:  J1032-1400
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  164  ,source name:  J0132-1654
# len_Xmatch =  37  len_FIRST =  0
# ================================================EOF================================================
# i =  165  ,source name:  J0617-2200
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  166  ,source name:  J0235-4737
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  167  ,source name:  J1554-2704
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  168  ,source name:  J2254-4139
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  169  ,source name:  J1019-2708
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  170  ,source name:  J0719-6218
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  171  ,source name:  J0241-0815
# len_Xmatch =  104  len_FIRST =  2
# ================================================EOF================================================
# i =  172  ,source name:  J1728+0427
# len_Xmatch =  10  len_FIRST =  0
# ================================================EOF================================================
# i =  173  ,source name:  J0949+1752
# len_Xmatch =  1  len_FIRST =  1
# ================================================EOF================================================
# i =  174  ,source name:  J0047+2435
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  175  ,source name:  J1131-0500
# len_Xmatch =  8  len_FIRST =  1
# ================================================EOF================================================
# i =  176  ,source name:  J1317+3425
# len_Xmatch =  4  len_FIRST =  3
# ================================================EOF================================================
# i =  177  ,source name:  J0833-7305
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  178  ,source name:  J1441-3303
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  179  ,source name:  J0915+0007
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  180  ,source name:  J0831-2228
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  181  ,source name:  J0205+3212
# len_Xmatch =  25  len_FIRST =  0
# ================================================EOF================================================
# i =  182  ,source name:  J0558-7459
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  183  ,source name:  J2211+1841
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  184  ,source name:  J2347-5110
# len_Xmatch =  5  len_FIRST =  0
# ================================================EOF================================================
# i =  185  ,source name:  J1446+1721
# len_Xmatch =  13  len_FIRST =  2
# ================================================EOF================================================
# i =  186  ,source name:  J0728-4745
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  187  ,source name:  J1006+0509
# len_Xmatch =  4  len_FIRST =  1
# ================================================EOF================================================
# i =  188  ,source name:  J0457-1819
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  189  ,source name:  J1838-3427
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  190  ,source name:  J1039-1541
# len_Xmatch =  5  len_FIRST =  0
# ================================================EOF================================================
# i =  191  ,source name:  J2257+0243
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  192  ,source name:  J0246-1236
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  193  ,source name:  J2148+0657
# len_Xmatch =  778  len_FIRST =  6
# ================================================EOF================================================
# i =  194  ,source name:  J0808-0751
# len_Xmatch =  20  len_FIRST =  0
# ================================================EOF================================================
# i =  195  ,source name:  J1658+3443
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  196  ,source name:  J1124-1501
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  197  ,source name:  J0653+3705
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  198  ,source name:  J0058-5219
# len_Xmatch =  15  len_FIRST =  0
# ================================================EOF================================================
# i =  199  ,source name:  J0608-1520
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  200  ,source name:  J0555+3948
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  201  ,source name:  J0325-2415
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  202  ,source name:  J0529-0519
# len_Xmatch =  9  len_FIRST =  0
# ================================================EOF================================================
# i =  203  ,source name:  J1832-5659
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  204  ,source name:  J0401+2110
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  205  ,source name:  J1419+2706
# len_Xmatch =  5  len_FIRST =  4
# ================================================EOF================================================
# i =  206  ,source name:  J1438-3122
# len_Xmatch =  5  len_FIRST =  0
# ================================================EOF================================================
# i =  207  ,source name:  J1454-2505
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  208  ,source name:  J1125-3557
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  209  ,source name:  J1243-2943
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  210  ,source name:  J2340+2641
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  211  ,source name:  J1829-5813
# len_Xmatch =  12  len_FIRST =  0
# ================================================EOF================================================
# i =  212  ,source name:  J2320+0513
# len_Xmatch =  13  len_FIRST =  6
# ================================================EOF================================================
# i =  213  ,source name:  J2236-1433
# len_Xmatch =  19  len_FIRST =  0
# ================================================EOF================================================
# i =  214  ,source name:  J0831+0429
# len_Xmatch =  24  len_FIRST =  2
# ================================================EOF================================================
# i =  215  ,source name:  J0125-2549
# len_Xmatch =  5  len_FIRST =  0
# ================================================EOF================================================
# i =  216  ,source name:  J0502+1338
# len_Xmatch =  4  len_FIRST =  0
# ================================================EOF================================================
# i =  217  ,source name:  J0956+2515
# len_Xmatch =  13  len_FIRST =  3
# ================================================EOF================================================
# i =  218  ,source name:  J0155+2230
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  219  ,source name:  J0237+0526
# len_Xmatch =  5  len_FIRST =  1
# ================================================EOF================================================
# i =  220  ,source name:  J0314-5104
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  221  ,source name:  J1453+2648
# len_Xmatch =  13  len_FIRST =  1
# ================================================EOF================================================
# i =  222  ,source name:  J2248-0541
# len_Xmatch =  1  len_FIRST =  6
# ================================================EOF================================================
# i =  223  ,source name:  J2135-5006
# len_Xmatch =  6  len_FIRST =  0
# ================================================EOF================================================
# i =  224  ,source name:  J0551-1909
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  225  ,source name:  J1536-3151
# len_Xmatch =  10  len_FIRST =  0
# ================================================EOF================================================
# i =  226  ,source name:  J2057-3734
# len_Xmatch =  9  len_FIRST =  0
# ================================================EOF================================================
# i =  227  ,source name:  J1513-3209
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  228  ,source name:  J0403-2444
# len_Xmatch =  6  len_FIRST =  0
# ================================================EOF================================================
# i =  229  ,source name:  J0049+0237
# len_Xmatch =  7  len_FIRST =  3
# ================================================EOF================================================
# i =  230  ,source name:  J1309+1154
# len_Xmatch =  2  len_FIRST =  2
# ================================================EOF================================================
# i =  231  ,source name:  J1524+1521
# len_Xmatch =  1  len_FIRST =  2
# ================================================EOF================================================
# i =  232  ,source name:  J0823+2928
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  233  ,source name:  J2145-3142
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  234  ,source name:  J0521+2112
# len_Xmatch =  36  len_FIRST =  0
# ================================================EOF================================================
# i =  235  ,source name:  J0058+3311
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  236  ,source name:  J0435+2532
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  237  ,source name:  J2318-4010
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  238  ,source name:  J2321+2732
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  239  ,source name:  J2256-2735
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  240  ,source name:  J1332-0509
# len_Xmatch =  12  len_FIRST =  5
# ================================================EOF================================================
# i =  241  ,source name:  J0811-7530
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  242  ,source name:  J0623-6436
# len_Xmatch =  8  len_FIRST =  0
# ================================================EOF================================================
# i =  243  ,source name:  J1129-4435
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  244  ,source name:  J0202-1948
# len_Xmatch =  4  len_FIRST =  0
# ================================================EOF================================================
# i =  245  ,source name:  J0513-2159
# len_Xmatch =  6  len_FIRST =  0
# ================================================EOF================================================
# i =  246  ,source name:  J0701-4634
# len_Xmatch =  36  len_FIRST =  0
# ================================================EOF================================================
# i =  247  ,source name:  J1813+0615
# len_Xmatch =  5  len_FIRST =  0
# ================================================EOF================================================
# i =  248  ,source name:  J2040-2507
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  249  ,source name:  J0301-1812
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  250  ,source name:  J0351-1153
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  251  ,source name:  J0746+2549
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  252  ,source name:  J1254+1141
# len_Xmatch =  10  len_FIRST =  1
# ================================================EOF================================================
# i =  253  ,source name:  J1116+0829
# len_Xmatch =  4  len_FIRST =  1
# ================================================EOF================================================
# i =  254  ,source name:  J1118-4634
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  255  ,source name:  J2358+1955
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  256  ,source name:  J1059-1134
# len_Xmatch =  4  len_FIRST =  0
# ================================================EOF================================================
# i =  257  ,source name:  J0435+2923
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  258  ,source name:  J1205-2634
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  259  ,source name:  J0332-1119
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  260  ,source name:  J0511+1357
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  261  ,source name:  J1129-0240
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  262  ,source name:  J1103+3014
# len_Xmatch =  6  len_FIRST =  6
# ================================================EOF================================================
# i =  263  ,source name:  J1425+1424
# len_Xmatch =  5  len_FIRST =  2
# ================================================EOF================================================
# i =  264  ,source name:  J0010+1058
# len_Xmatch =  24  len_FIRST =  4
# ================================================EOF================================================
# i =  265  ,source name:  J1018-3123
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  266  ,source name:  J1254-4424
# len_Xmatch =  12  len_FIRST =  0
# ================================================EOF================================================
# i =  267  ,source name:  J1624-6809
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  268  ,source name:  J0610-6058
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  269  ,source name:  J0336+3218
# len_Xmatch =  75  len_FIRST =  0
# ================================================EOF================================================
# i =  270  ,source name:  J1232-0224
# len_Xmatch =  14  len_FIRST =  3
# ================================================EOF================================================
# i =  271  ,source name:  J0049-5738
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  272  ,source name:  J1925-2219
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  273  ,source name:  J2056-3208
# len_Xmatch =  9  len_FIRST =  0
# ================================================EOF================================================
# i =  274  ,source name:  J1012-3740
# len_Xmatch =  4  len_FIRST =  0
# ================================================EOF================================================
# i =  275  ,source name:  J1501-3828
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  276  ,source name:  J2115+2933
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  277  ,source name:  J1331-0341
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  278  ,source name:  J2359-3133
# len_Xmatch =  20  len_FIRST =  0
# ================================================EOF================================================
# i =  279  ,source name:  J1016+0513
# len_Xmatch =  5  len_FIRST =  1
# ================================================EOF================================================
# i =  280  ,source name:  J0943+1702
# len_Xmatch =  1  len_FIRST =  1
# ================================================EOF================================================
# i =  281  ,source name:  J2209-4710
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  282  ,source name:  J0215-0222
# len_Xmatch =  33  len_FIRST =  2
# ================================================EOF================================================
# i =  283  ,source name:  J2319-4206
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  284  ,source name:  J1048-1909
# len_Xmatch =  16  len_FIRST =  0
# ================================================EOF================================================
# i =  285  ,source name:  J1508-1548
# len_Xmatch =  5  len_FIRST =  0
# ...
# i =  1273  ,source name:  J0143-3200
# len_Xmatch =  18  len_FIRST =  0
# ================================================EOF================================================
# i =  1274  ,source name:  J1252-3319
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1275  ,source name:  J0522-0725
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1276  ,source name:  J2039-7206
# len_Xmatch =  5  len_FIRST =  0
# ================================================EOF================================================
# i =  1277  ,source name:  J2025-0735
# len_Xmatch =  14  len_FIRST =  0
# ================================================EOF================================================
# i =  1278  ,source name:  J1449-2139
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1279  ,source name:  J0334+0800
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1280  ,source name:  J0102-7546
# len_Xmatch =  44  len_FIRST =  0
# ================================================EOF================================================
# i =  1281  ,source name:  J1330-3122
# len_Xmatch =  9  len_FIRST =  0
# ================================================EOF================================================
# i =  1282  ,source name:  J1121-0442
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  1283  ,source name:  J1443+2501
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  1284  ,source name:  J1011+0106
# len_Xmatch =  4  len_FIRST =  1
# ================================================EOF================================================
# i =  1285  ,source name:  J1802-3940
# len_Xmatch =  33  len_FIRST =  0
# ================================================EOF================================================
# i =  1286  ,source name:  J1354-0206
# len_Xmatch =  4  len_FIRST =  1
# ================================================EOF================================================
# i =  1287  ,source name:  J1159+2914
# len_Xmatch =  23  len_FIRST =  1
# ================================================EOF================================================
# i =  1288  ,source name:  J2313-3704
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  1289  ,source name:  J2246-5607
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  1290  ,source name:  J0901-0702
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1291  ,source name:  J1207+2754
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  1292  ,source name:  J0006-4245
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1293  ,source name:  J0058-3234
# len_Xmatch =  14  len_FIRST =  0
# ================================================EOF================================================
# i =  1294  ,source name:  J0301+0118
# len_Xmatch =  21  len_FIRST =  1
# ================================================EOF================================================
# i =  1295  ,source name:  J1058-0309
# len_Xmatch =  2  len_FIRST =  2
# ================================================EOF================================================
# i =  1296  ,source name:  J1409-2657
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  1297  ,source name:  J1441-1523
# len_Xmatch =  4  len_FIRST =  0
# ================================================EOF================================================
# i =  1298  ,source name:  J0517-0520
# len_Xmatch =  17  len_FIRST =  0
# ================================================EOF================================================
# i =  1299  ,source name:  J1728+1215
# len_Xmatch =  18  len_FIRST =  0
# ================================================EOF================================================
# i =  1300  ,source name:  J1616-7108
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  1301  ,source name:  J0405-1308
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  1302  ,source name:  J2206-2119
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  1303  ,source name:  J1326-5256
# len_Xmatch =  23  len_FIRST =  0
# ================================================EOF================================================
# i =  1304  ,source name:  J1436+2321
# len_Xmatch =  2  len_FIRST =  1
# ================================================EOF================================================
# i =  1305  ,source name:  J1937-3958
# len_Xmatch =  11  len_FIRST =  0
# ================================================EOF================================================
# i =  1306  ,source name:  J1104-2431
# len_Xmatch =  6  len_FIRST =  0
# ================================================EOF================================================
# i =  1307  ,source name:  J2256-6533
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1308  ,source name:  J0151+2744
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  1309  ,source name:  J0046+3900
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  1310  ,source name:  J1108+0811
# len_Xmatch =  7  len_FIRST =  6
# ================================================EOF================================================
# i =  1311  ,source name:  J0138-2711
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1312  ,source name:  J2207-5346
# len_Xmatch =  20  len_FIRST =  0
# ================================================EOF================================================
# i =  1313  ,source name:  J2042-2223
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1314  ,source name:  J1533-0421
# len_Xmatch =  7  len_FIRST =  2
# ================================================EOF================================================
# i =  1315  ,source name:  J1121-0553
# len_Xmatch =  2  len_FIRST =  4
# ================================================EOF================================================
# i =  1316  ,source name:  J0343-2530
# len_Xmatch =  4  len_FIRST =  0
# ================================================EOF================================================
# i =  1317  ,source name:  J0538-4405
# len_Xmatch =  802  len_FIRST =  0
# ================================================EOF================================================
# i =  1318  ,source name:  J1135-0428
# len_Xmatch =  5  len_FIRST =  1
# ================================================EOF================================================
# i =  1319  ,source name:  J0145-2733
# len_Xmatch =  15  len_FIRST =  0
# ================================================EOF================================================
# i =  1320  ,source name:  J0327+0044
# len_Xmatch =  11  len_FIRST =  2
# ================================================EOF================================================
# i =  1321  ,source name:  J0743-5619
# len_Xmatch =  16  len_FIRST =  0
# ================================================EOF================================================
# i =  1322  ,source name:  J1949-1957
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  1323  ,source name:  J2017-3753
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  1324  ,source name:  J1419-0838
# len_Xmatch =  15  len_FIRST =  0
# ================================================EOF================================================
# i =  1325  ,source name:  J1939-1525
# len_Xmatch =  9  len_FIRST =  0
# ================================================EOF================================================
# i =  1326  ,source name:  J0909+0200
# len_Xmatch =  10  len_FIRST =  1
# ================================================EOF================================================
# i =  1327  ,source name:  J0421-4818
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1328  ,source name:  J0608-2220
# len_Xmatch =  9  len_FIRST =  0
# ================================================EOF================================================
# i =  1329  ,source name:  J0953+1720
# len_Xmatch =  1  len_FIRST =  1
# ================================================EOF================================================
# i =  1330  ,source name:  J2101-2933
# len_Xmatch =  23  len_FIRST =  0
# ================================================EOF================================================
# i =  1331  ,source name:  J2314-3138
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1332  ,source name:  J0102-2646
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1333  ,source name:  J0448-3659
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1334  ,source name:  J1335-0511
# len_Xmatch =  2  len_FIRST =  6
# ================================================EOF================================================
# i =  1335  ,source name:  J0039+1411
# len_Xmatch =  2  len_FIRST =  2
# ================================================EOF================================================
# i =  1336  ,source name:  J1405+0415
# len_Xmatch =  9  len_FIRST =  1
# ================================================EOF================================================
# i =  1337  ,source name:  J1513-1012
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  1338  ,source name:  J1012+2312
# len_Xmatch =  7  len_FIRST =  1
# ================================================EOF================================================
# i =  1339  ,source name:  J2101+0341
# len_Xmatch =  16  len_FIRST =  11
# ================================================EOF================================================
# i =  1340  ,source name:  J2343+2339
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  1341  ,source name:  J0309-6058
# len_Xmatch =  11  len_FIRST =  0
# ================================================EOF================================================
# i =  1342  ,source name:  J0013-0423
# len_Xmatch =  10  len_FIRST =  3
# ================================================EOF================================================
# i =  1343  ,source name:  J2011-1546
# len_Xmatch =  11  len_FIRST =  0
# ================================================EOF================================================
# i =  1344  ,source name:  J1653+3107
# len_Xmatch =  9  len_FIRST =  1
# ================================================EOF================================================
# i =  1345  ,source name:  J1546-6837
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  1346  ,source name:  J0048+3157
# len_Xmatch =  7  len_FIRST =  0
# ================================================EOF================================================
# i =  1347  ,source name:  J2354-1513
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1348  ,source name:  J0010+1724
# len_Xmatch =  9  len_FIRST =  0
# ================================================EOF================================================
# i =  1349  ,source name:  J1457-3539
# len_Xmatch =  12  len_FIRST =  0
# ================================================EOF================================================
# i =  1350  ,source name:  J0159-2740
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  1351  ,source name:  J0724-0715
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  1352  ,source name:  J1307-3207
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1353  ,source name:  J0532+0732
# len_Xmatch =  56  len_FIRST =  0
# ================================================EOF================================================
# i =  1354  ,source name:  J0825+2704
# len_Xmatch =  5  len_FIRST =  1
# ================================================EOF================================================
# i =  1355  ,source name:  J0920-2956
# len_Xmatch =  6  len_FIRST =  0
# ================================================EOF================================================
# i =  1356  ,source name:  J2043+1255
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1357  ,source name:  J1743-0350
# len_Xmatch =  58  len_FIRST =  0
# ================================================EOF================================================
# i =  1358  ,source name:  J1118+1234
# len_Xmatch =  24  len_FIRST =  2
# ================================================EOF================================================
# i =  1359  ,source name:  J2130-0927
# len_Xmatch =  10  len_FIRST =  0
# ================================================EOF================================================
# i =  1360  ,source name:  J0909+0121
# len_Xmatch =  81  len_FIRST =  3
# ================================================EOF================================================
# i =  1361  ,source name:  J0220-1305
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  1362  ,source name:  J0505-2930
# len_Xmatch =  2  len_FIRST =  0
# ================================================EOF================================================
# i =  1363  ,source name:  J1259-2310
# len_Xmatch =  3  len_FIRST =  0
# ================================================EOF================================================
# i =  1364  ,source name:  J2015+3710
# len_Xmatch =  10  len_FIRST =  0
# ================================================EOF================================================
# i =  1365  ,source name:  J1827-4533
# len_Xmatch =  1  len_FIRST =  0
# ================================================EOF================================================
# i =  1366  ,source name:  J0005+3820
# len_Xmatch =  4  len_FIRST =  0
# ================================================EOF================================================

# %%
## find sources which Have FIRST data
aa = []

SAVEpath = '/Users/87steven/Documents/ASIAA/SED progress'

for j in range(2, len(FIRST.RA_hh)-1): 
    
    print('j = ', j)

    RA_F  = f'{FIRST.RA_hh[j]} {FIRST.RA_mm[j]} {float(FIRST.RA_ss[j])}'
    DEC_F = f'{FIRST.DEC_dd[j]} {FIRST.DEC_mm[j]} {float(FIRST.DEC_ss[j])}'

    check = True
    if check:
        for i, Dataname in enumerate(set(Xmatch.name[0:len(Xmatch.RA_hh)-1])): # enumerate(set(Xmatch.name[0:len(Xmatch.RA_hh)-1]))
    
        #print('i = ', i, ' ,source name =', Dataname)    
            df = ClearData()
    
            RAX_hh = Xmatch['RA_hh'][Xmatch['name'] == Dataname].values[0] # RA_hh which name is consist with "Dataname", than extract it value (.values[0])
            RAX_mm = Xmatch['RA_mm'][Xmatch['name'] == Dataname].values[0]
            RAX_ss = Xmatch['RA_ss'][Xmatch['name'] == Dataname].values[0]
            DECX_dd = Xmatch['DEC_dd'][Xmatch['name'] == Dataname].values[0]
            DECX_mm = Xmatch['DEC_mm'][Xmatch['name'] == Dataname].values[0]
            DECX_ss = Xmatch['DEC_ss'][Xmatch['name'] == Dataname].values[0]
    
            RA_X  = f'{RAX_hh} {RAX_mm} {RAX_ss}' 
            DEC_X = f'{DECX_dd} {DECX_mm} {DECX_ss}' 

            if str(RA_F == RA_X) == 'True':

                print('j = ', j, ' ,Have FIRST data')
                
                aa.append(Dataname)
            
                check = False
                
    print('================================================END=============================================')

filename = 'HAVE FIRST data'
CSVfile = f'{SAVEpath}/{filename}.csv'    
dff = pd.DataFrame(aa)      
dff.to_csv(CSVfile, index = False)

# %%
aa
