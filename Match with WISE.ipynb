# %%
import pandas as pd
import numpy as np
import re

Xmatch = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/BZCAT_Xmatch_ACC_csv.csv') # # = 37671
WISE = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/WISE_4_18.csv')  # # = 8499

def ClearData():
    data = {'Name': [],
    'RA': [],
    'DEC': [],
    'z': [], 
    'Rmag': [],
    'class': [],
    'flux_ratio': [],
    'flux_143': [], 
    'flux_xray': [],
    'flux_gamma': [],
    'Spec_index': [], 
    'flux_ALMA': [], 
    'errflux': [], 
    'band': [],
    'freq': [],
    'date': [],
    'distance': [],
    'W1mag': [], # WISE
    'eW1mag': [],
    'W2mag': [], 
    'eW2mag': [] ,
    'W3mag': [],
    'eW3mag': [],
    'W4mag': [],
    'eW4mag': [],
    'Jmag': [],
    'eJmag': [],
    'Hmag': [], 
    'eHmag': [] ,
    'Kmag': [],
    'eKmag':[]   }
    return data

### to remove '\t\t\t\t'
#for i in range(0, len(WISE)): #len(WISE)
#    for j in range(0 , len(WISE.values[i])):
#        WISE.values[i][j] = re.sub('\s+', 'nan', str(WISE.values[i][j]))

for i in range(0, len(WISE)): #len(WISE)
    for j in range(0 , len(WISE.values[i])):
        WISE.values[i][j] = re.sub('\s+', 'nan', str(WISE.values[i][j]))

# %%
#######################################################################################################
#######################################################################################################
#######################################################################################################
### Extract all data which match with the center

for i, Dataname in enumerate(set(Xmatch.name[0:len(Xmatch.RA_hh)-1])): # enumerate(set(Xmatch.name[0:len(Xmatch.RA_hh)-1]))
    # set: find every name
    # enumerate: add index and list out the name
    
    print('i = ',i, ' ,source name: ', Dataname)    
    df = ClearData()
    
    RAX_hh = Xmatch['RA_hh'][Xmatch['name'] == Dataname].values[0] # RA_hh which name is consist with "Dataname", than extract it value (.values[0])
    RAX_mm = Xmatch['RA_mm'][Xmatch['name'] == Dataname].values[0]
    RAX_ss = Xmatch['RA_ss'][Xmatch['name'] == Dataname].values[0]
    DECX_dd = Xmatch['DEC_dd'][Xmatch['name'] == Dataname].values[0]
    DECX_mm = Xmatch['DEC_mm'][Xmatch['name'] == Dataname].values[0]
    DECX_ss = Xmatch['DEC_ss'][Xmatch['name'] == Dataname].values[0]
    
    # combine Xmatch coordinates into a string array
    RA_X  = f'{RAX_hh} {RAX_mm} {RAX_ss}' # sort RA in to a string array (f'')
    DEC_X = f'{DECX_dd} {DECX_mm} {DECX_ss}' # sort RA in to a string array
    
    writeXmatch = True
    for j in range(2, len(WISE.RA_hh)-1): #range(2, 8): # range(2, len(WISE.RA_hh)-1): *** MUST start from 2***
        
        RA_W  = f'{WISE.RA_hh[j]} {WISE.RA_mm[j]} {float(WISE.RA_ss[j])}'
        DEC_W = f'{WISE.DEC_dd[j]} {WISE.DEC_mm[j]} {float(WISE.DEC_ss[j])}'

        if (RA_X == RA_W):
            
            if writeXmatch: # if true
                
                ### in order to find the index of the same name
                Index = Xmatch[Xmatch['name'] == Dataname].index.tolist() # convert the index into a list 

                for x in Index: 
                    
                    df['Name'].append(Xmatch.name[x])
                    df['RA'].append(Xmatch.RA[x])
                    df['DEC'].append(Xmatch.DEC[x])
                    df['z'].append(Xmatch.z[x])
                    df['Rmag'].append(Xmatch.Rmag[x])
                    df['class'].append(Xmatch.Class[x])
                    df['band'].append(Xmatch.band[x])
                    df['freq'].append(Xmatch.freq[x])
                    df['date'].append(Xmatch.date[x])
                    df['flux_ratio'].append(Xmatch.flux_ratio[x])
                    df['flux_143'].append(Xmatch.flux_143[x])
                    df['flux_xray'].append(Xmatch.flux_xray[x])
                    df['flux_gamma'].append(Xmatch.flux_gamma[x])
                    df['Spec_index'].append(Xmatch.Spec_index[x]) 
                    df['flux_ALMA'].append(Xmatch.flux_ALMA[x])
                    df['errflux'].append(Xmatch.errflux[x])   
                    
                writeXmatch = False
                
            if not np.isnan(float(WISE.W1mag[j])): # if Ftot is not NaN
                
                df['distance'].append(float(WISE._r[j])) 
                df['W1mag'].append(float(WISE.W1mag[j]))
                df['eW1mag'].append(float(WISE.e_W1mag[j]))
                df['W2mag'].append(float(WISE.W2mag[j]))
                df['eW2mag'].append(float(WISE.e_W2mag[j]))
                df['W3mag'].append(float(WISE.W3mag[j]))
                df['eW3mag'].append(float(WISE.e_W3mag[j]))
                df['W4mag'].append(float(WISE.W4mag[j]))
                df['eW4mag'].append(float(WISE.e_W4mag[j]))
                df['Jmag'].append(float(WISE.Jmag[j]))
                df['eJmag'].append(float(WISE.e_Jmag[j][:5]))
                df['Hmag'].append(float(WISE.Hmag[j][:5]))
                df['eHmag'].append(float(WISE.e_Hmag[j][:5]))
                df['Kmag'].append(float(WISE.Kmag[j][:5]))
                df['eKmag'].append(float(WISE.e_Kmag[j][:5]))

                #print('WISE size = ', len(df['Ftot']))
                
            else:
                
                #print('no WISE data')
                df['distance'].append(np.nan)
                df['W1mag'].append(np.nan)
                df['eW1mag'].append(np.nan)
                df['W2mag'].append(np.nan)
                df['eW2mag'].append(np.nan)
                df['W3mag'].append(np.nan)
                df['eW3mag'].append(np.nan)
                df['W4mag'].append(np.nan)
                df['eW4mag'].append(np.nan)
                df['Jmag'].append(np.nan)
                df['eJmag'].append(np.nan)
                df['Hmag'].append(np.nan)
                df['eHmag'].append(np.nan)
                df['Kmag'].append(np.nan)
                df['eKmag'].append(np.nan)
                
        else:
            
            if writeXmatch: # if true
                
                ### in order to find the index of the same name
                Index = Xmatch[Xmatch['name'] == Dataname].index.tolist() # convert the index into a list 

                for x in Index: 
                    
                    df['Name'].append(Xmatch.name[x])
                    df['RA'].append(Xmatch.RA[x])
                    df['DEC'].append(Xmatch.DEC[x])
                    df['z'].append(Xmatch.z[x])
                    df['Rmag'].append(Xmatch.Rmag[x])
                    df['class'].append(Xmatch.Class[x])
                    df['band'].append(Xmatch.band[x])
                    df['freq'].append(Xmatch.freq[x])
                    df['date'].append(Xmatch.date[x])
                    df['flux_ratio'].append(Xmatch.flux_ratio[x])
                    df['flux_143'].append(Xmatch.flux_143[x])
                    df['flux_xray'].append(Xmatch.flux_xray[x])
                    df['flux_gamma'].append(Xmatch.flux_gamma[x])
                    df['Spec_index'].append(Xmatch.Spec_index[x]) 
                    df['flux_ALMA'].append(Xmatch.flux_ALMA[x])
                    df['errflux'].append(Xmatch.errflux[x])   
                    
                writeXmatch = False
                
    len_Xmatch = len(df['Name'])
    len_WISE  = len(df['W1mag'])
    
    print('len_Xmatch = ', len_Xmatch, ' len_WISE = ', len_WISE)
    
    # Xmatch data number > WISE data number
    if len_Xmatch > len_WISE:
        
        difflen = len_Xmatch - len_WISE
        
        for ii in range(difflen):
            
            df['distance'].append(np.nan)
            df['W1mag'].append(np.nan)
            df['eW1mag'].append(np.nan)
            df['W2mag'].append(np.nan)
            df['eW2mag'].append(np.nan)
            df['W3mag'].append(np.nan)
            df['eW3mag'].append(np.nan)
            df['W4mag'].append(np.nan)
            df['eW4mag'].append(np.nan)
            df['Jmag'].append(np.nan)
            df['eJmag'].append(np.nan)
            df['Hmag'].append(np.nan)
            df['eHmag'].append(np.nan)
            df['Kmag'].append(np.nan)
            df['eKmag'].append(np.nan)

    # WISE data number > Xmatch data number
    elif len_Xmatch < len_WISE:
        
        difflen = abs(len_Xmatch - len_WISE)
        
        for ii in range(difflen):
            
            df['Name'].append(Xmatch.name[x])
            df['RA'].append(Xmatch.RA[x])
            df['DEC'].append(Xmatch.DEC[x])
            df['z'].append(Xmatch.z[x])
            df['Rmag'].append(Xmatch.Rmag[x])
            df['class'].append(Xmatch.Class[x])            
            df['band'].append(np.nan)
            df['freq'].append(np.nan)
            df['date'].append(np.nan)
            df['flux_ratio'].append(np.nan)
            df['flux_143'].append(np.nan)
            df['flux_xray'].append(np.nan)
            df['flux_gamma'].append(np.nan)
            df['Spec_index'].append(np.nan)
            df['flux_ALMA'].append(np.nan)
            df['errflux'].append(np.nan)

    CSVfile = f'/Users/87steven/Documents/ASIAA/Blazar SED code and data/WISE match 2/{Dataname}.csv'    
    dff = pd.DataFrame(df)      
    dff.to_csv(CSVfile, index = False)
    
    print('================================================EOF================================================')

# %%
#######################################################################################################
## find sources which Have VLASS data (2023/2/3 made)
#######################################################################################################
import pandas as pd
import numpy as np

Xmatch = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/BZCAT_Xmatch_ACC_csv.csv') # # = 37671
RAX_hh = Xmatch['RA_hh'].values
RAX_mm = Xmatch['RA_mm'].values
RAX_ss = Xmatch['RA_ss'].values
DECX_dd = Xmatch['DEC_dd'].values
DECX_mm = Xmatch['DEC_mm'].values
DECX_ss = Xmatch['DEC_ss'].values
    
WISE = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/WISE.csv')  # # = 8499
RA_hh = WISE['RA_hh'].values
RA_mm = WISE['RA_mm'].values
RA_ss = WISE['RA_ss'].values
DEC_dd = WISE['DEC_dd'].values
DEC_mm = WISE['DEC_mm'].values
DEC_ss = WISE['DEC_ss'].values

coordinate_X = [None]*len(Xmatch['RA_hh'])
for i in range(0, len(Xmatch['RA_hh'])):
    coordinate_X[i] = f'{RAX_hh[i]} {RAX_mm[i]} {RAX_ss[i]} {DECX_dd[i]} {DECX_mm[i]} {DECX_ss[i]}'
    
coordinate = [None]*(len(RA_hh))
for k in range(0, len(RA_hh)-1):
    coordinate[k] = f'{RA_hh[k]} {RA_mm[k]} {RA_ss[k]} {DEC_dd[k]} {DEC_mm[k]} {DEC_ss[k]}' 
    
coordinate_X = list(set(coordinate_X))
coordinate = list(set(coordinate))

aa = []
for i in range(0, len(coordinate_X)):
    for k in range(0, len(coordinate)):
        if coordinate_X[i] == coordinate[k]:
            aa.append([i, k])
            
print(len(aa), 'of sources have matched sources with ACC and BZCAT')
print(len(coordinate_X)-len(aa), 'of sources NO matched sources with ACC and BZCAT')
# Out:
# 1320 of sources have matched sources with ACC and BZCAT
# 47 of sources NO matched sources with ACC and BZCAT
