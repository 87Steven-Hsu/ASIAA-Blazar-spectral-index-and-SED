# %%
import pandas as pd
import numpy as np

Xmatch = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/BZCAT_Xmatch_ACC_csv.csv') # # = 37671
XMM = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/XMM-OM_csv.csv')  # # = 8499

def ClearData():
    data = {'Name': [],
    'RA': [],
    'DEC': [],
    'z': [], 
    'Rmag': [],
    'class': [],
    'flux_ratio': [],
    'flux_143': [], 
    'flux_xray': [],
    'flux_gamma': [],
    'Spec_index': [], 
    'flux_ALMA': [], 
    'errflux': [], 
    'band': [],
    'freq': [],
    'date': [],
    'UVW2': [],
    'e_UVW2': [],
    'UVM2': [], 
    'e_UVM2': [],
    'UVW1': [],
    'e_UVW1': [],
    'U': [], 
    'e_U': [],
    'B': [], 
    'e_B': [],
    'V': [], 
    'e_V': []  }
    return data

# %%
for i, Dataname in enumerate(set(Xmatch.name)): # enumerate(set(Xmatch.name[0:len(Xmatch.RA_hh)-1]))
#for i in range(422, 423): 
    # set: find every name
    # enumerate: add index and list out the name
    
    #Dataname = str('J0413-5332')
    print('i = ',i, ' ,source name: ', Dataname)    
    df = ClearData()
    
    RAX_hh = Xmatch['RA_hh'][Xmatch['name'] == Dataname].values[0] # RA_hh which name is consist with "Dataname", than extract it value (.values[0])
    RAX_mm = Xmatch['RA_mm'][Xmatch['name'] == Dataname].values[0]
    RAX_ss = Xmatch['RA_ss'][Xmatch['name'] == Dataname].values[0]
    DECX_dd = Xmatch['DEC_dd'][Xmatch['name'] == Dataname].values[0]
    DECX_mm = Xmatch['DEC_mm'][Xmatch['name'] == Dataname].values[0]
    DECX_ss = Xmatch['DEC_ss'][Xmatch['name'] == Dataname].values[0]
    
    # combine Xmatch coordinates into a string array
    RA_X  = f'{RAX_hh} {RAX_mm} {RAX_ss}' # sort RA in to a string array (f'')
    DEC_X = f'{DECX_dd} {DECX_mm} {DECX_ss}' # sort RA in to a string array
    
    writeXmatch = True
    for j in range(2, len(XMM.RA_hh)-1): #range(2, 8): # range(2, len(VLASS.RA_hh)-1): *** MUST start from 2***
        
        RA_XMM = f'{XMM.RA_hh[j]} {XMM.RA_mm[j]} { XMM.RA_ss[j]}'
        DEC_XMM = f'{XMM.DEC_dd[j]} {XMM.DEC_mm[j]} {XMM.DEC_ss[j]}'

        if (RA_X == RA_XMM):
            
            if writeXmatch: # if true
                
                ### in order to find the index of the same name
                Index = Xmatch[Xmatch['name'] == Dataname].index.tolist() # convert the index into a list 

                for x in Index: 
                    
                    df['Name'].append(Xmatch.name[x])
                    df['RA'].append(Xmatch.RA[x])
                    df['DEC'].append(Xmatch.DEC[x])
                    df['z'].append(Xmatch.z[x])
                    df['Rmag'].append(Xmatch.Rmag[x])
                    df['class'].append(Xmatch.Class[x])
                    df['band'].append(Xmatch.band[x])
                    df['freq'].append(Xmatch.freq[x])
                    df['date'].append(Xmatch.date[x])
                    df['flux_ratio'].append(Xmatch.flux_ratio[x])
                    df['flux_143'].append(Xmatch.flux_143[x])
                    df['flux_xray'].append(Xmatch.flux_xray[x])
                    df['flux_gamma'].append(Xmatch.flux_gamma[x])
                    df['Spec_index'].append(Xmatch.Spec_index[x]) 
                    df['flux_ALMA'].append(Xmatch.flux_ALMA[x])
                    df['errflux'].append(Xmatch.errflux[x])   
                    
                writeXmatch = False
                
            #if len(XMM.U[j]) == 12:
            #    XMM.U[j] = np.nan
            #if len(XMM.e_U[j]) == 12:
            #    XMM.e_U[j] = np.nan
            #if len(XMM.B[j]) == 12:
            #    XMM.B[j] = np.nan
            #if len(XMM.e_B[j]) == 12:
            #    XMM.e_B[j] = np.nan
            #if len(XMM.V[j]) == 12:
            #    XMM.V[j] = np.nan
            
            
            if not np.isnan( float(XMM.UVW2[j]) ): # if Ftot is not NaN
               
                df['UVW2'].append(float(XMM.UVW2[j]))
                df['e_UVW2'].append(float(XMM.e_UVW2[j]))
                df['UVM2'].append(float(XMM.UVM2[j]))
                df['e_UVM2'].append(float(XMM.e_UVM2[j]))
                df['UVW1'].append(float(XMM.UVW1[j]))
                df['e_UVW1'].append(float(XMM.e_UVW1[j]))
                df['U'].append(float(XMM.U[j]))
                df['e_U'].append(float(XMM.e_U[j]))
                df['B'].append(float(XMM.B[j]))
                df['e_B'].append(float(XMM.e_B[j]))
                df['V'].append(float(XMM.V[j]))
                df['e_V'].append(float(XMM.e_V[j]))
                                    
        else:
                
            if writeXmatch: # if true
                
                ### in order to find the index of the same name
                Index = Xmatch[Xmatch['name'] == Dataname].index.tolist() # convert the index into a list 

                for x in Index: 
                    
                    df['Name'].append(Xmatch.name[x])
                    df['RA'].append(Xmatch.RA[x])
                    df['DEC'].append(Xmatch.DEC[x])
                    df['z'].append(Xmatch.z[x])
                    df['Rmag'].append(Xmatch.Rmag[x])
                    df['class'].append(Xmatch.Class[x])
                    df['band'].append(Xmatch.band[x])
                    df['freq'].append(Xmatch.freq[x])
                    df['date'].append(Xmatch.date[x])
                    df['flux_ratio'].append(Xmatch.flux_ratio[x])
                    df['flux_143'].append(Xmatch.flux_143[x])
                    df['flux_xray'].append(Xmatch.flux_xray[x])
                    df['flux_gamma'].append(Xmatch.flux_gamma[x])
                    df['Spec_index'].append(Xmatch.Spec_index[x]) 
                    df['flux_ALMA'].append(Xmatch.flux_ALMA[x])
                    df['errflux'].append(Xmatch.errflux[x])   

                writeXmatch = False

                
    len_Xmatch = len(df['Name'])
    len_XMM  = len(df['UVW2'])
    
    print('len_Xmatch = ', len_Xmatch, ' len_XMM = ', len_XMM)
    
    # Xmatch data number > VLASS data number
    if len_Xmatch > len_XMM:
        
        difflen = len_Xmatch - len_XMM
        
        for ii in range(difflen):
            
            df['UVW2'].append( np.nan )
            df['e_UVW2'].append( np.nan )
            df['UVM2'].append( np.nan )
            df['e_UVM2'].append( np.nan )
            df['UVW1'].append( np.nan )
            df['e_UVW1'].append( np.nan )
            df['U'].append( np.nan )
            df['e_U'].append( np.nan )
            df['B'].append( np.nan )
            df['e_B'].append( np.nan )
            df['V'].append( np.nan )
            df['e_V'].append( np.nan )
            
    # VLASS data number > Xmatch data number
    elif len_Xmatch < len_XMM:
        
        difflen = abs(len_Xmatch - len_XMM)
        #difflen = len_VLASS - len_Xmatch
        
        for ii in range(difflen):
            
            df['Name'].append(Xmatch.name[x])
            df['RA'].append(Xmatch.RA[x])
            df['DEC'].append(Xmatch.DEC[x])
            df['z'].append(Xmatch.z[x])
            df['Rmag'].append(Xmatch.Rmag[x])
            df['class'].append(Xmatch.Class[x])
            df['band'].append(np.nan)
            df['freq'].append(np.nan)
            df['date'].append(np.nan)
            df['flux_ratio'].append(np.nan)
            df['flux_143'].append(np.nan)
            df['flux_xray'].append(np.nan)
            df['flux_gamma'].append(np.nan)
            df['Spec_index'].append(np.nan)
            df['flux_ALMA'].append(np.nan)
            df['errflux'].append(np.nan)
            
    #print(pd.DataFrame(df))
    
    SAVEpath = '/Users/87steven/Documents/ASIAA/Blazar SED code and data/XMM match'   
    
    CSVfile = f'{SAVEpath}/{Dataname}.csv'    
    dff = pd.DataFrame(df)      
    dff.to_csv(CSVfile, index = False)
    
    print('================================================EOF================================================')

# %%
#######################################################################################################
## find sources which Have VLASS data (2023/2/3 made)
#######################################################################################################
import pandas as pd
import numpy as np

Xmatch = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/BZCAT_Xmatch_ACC_csv.csv') # # = 37671
RAX_hh = Xmatch['RA_hh'].values
RAX_mm = Xmatch['RA_mm'].values
RAX_ss = Xmatch['RA_ss'].values
DECX_dd = Xmatch['DEC_dd'].values
DECX_mm = Xmatch['DEC_mm'].values
DECX_ss = Xmatch['DEC_ss'].values
    
XMM_OM = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/XMM-OM_csv.csv')  # # = 8499
RA_hh = XMM_OM['RA_hh'].values
RA_mm = XMM_OM['RA_mm'].values
RA_ss = XMM_OM['RA_ss'].values
DEC_dd = XMM_OM['DEC_dd'].values
DEC_mm = XMM_OM['DEC_mm'].values
DEC_ss = XMM_OM['DEC_ss'].values

coordinate_X = [None]*len(Xmatch['RA_hh'])
for i in range(0, len(Xmatch['RA_hh'])):
    coordinate_X[i] = f'{RAX_hh[i]} {RAX_mm[i]} {RAX_ss[i]} {DECX_dd[i]} {DECX_mm[i]} {DECX_ss[i]}'
    
coordinate = [None]*(len(RA_hh))
for k in range(0, len(RA_hh)-1):
    coordinate[k] = f'{RA_hh[k]} {RA_mm[k]} {RA_ss[k]} {DEC_dd[k]} {DEC_mm[k]} {DEC_ss[k]}' 
    
coordinate_X = list(set(coordinate_X))
coordinate = list(set(coordinate))

aa = []
for i in range(0, len(coordinate_X)):
    for k in range(0, len(coordinate)):
        if coordinate_X[i] == coordinate[k]:
            aa.append([i, k])
            
print(len(aa), 'of sources have matched sources with ACC and BZCAT')
print(len(coordinate_X)-len(aa), 'of sources NO matched sources with ACC and BZCAT')
# Out:
# 74 of sources have matched sources with ACC and BZCAT
# 1293 of sources NO matched sources with ACC and BZCAT
