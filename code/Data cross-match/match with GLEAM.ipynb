# %%
import pandas as pd
import numpy as np

Xmatch = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/BZCAT_Xmatch_ACC_csv.csv') # # = 37671
GLEAM = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/GLEAM_csv.csv')  # # = 8499

##please add your destination path to save .csv file
SAVEpath = '/Users/87steven/Documents/ASIAA/Blazar SED code and data/GLEAM match'   

def ClearData():
    data = {'Name': [],
    'RA': [],
    'DEC': [],
    'z': [], 
    'Rmag': [],
    'class': [],
    'flux_ratio': [],
    'flux_143': [], 
    'flux_xray': [],
    'flux_gamma': [],
    'Spec_index': [], 
    'flux_ALMA': [], 
    'errflux': [], 
    'band': [],
    'freq': [],
    'date': [], # Xmatch end
    'Fpwide': [], # GLEAM start
    'e_Fpwide': [],
    'Fintwide': [],
    'e_Fintwide': [],
    'Fp076': [],
    'e_Fp076': [],
    'Fint076': [],
    'e_Fint076': [],
    'Fp084': [],
    'e_Fp084': [],
    'Fint084': [],
    'e_Fint084': [],
    'Fp092': [],
    'e_Fp092': [],
    'Fint092': [],
    'e_Fint092': [],
    'Fp099': [],
    'e_Fp099': [],
    'Fint099': [],
    'e_Fint099': [],
    'Fp107': [],
    'e_Fp107': [],
    'Fint107': [],
    'e_Fint107': [],
    'Fp115': [],
    'e_Fp115': [],
    'Fint115': [],
    'e_Fint115': [],
    'Fp122': [],
    'e_Fp122': [],
    'Fint122': [],
    'e_Fint122': [],
    'Fp130': [],
    'e_Fp130': [],
    'Fint130': [],
    'e_Fint130': [],
    'Fp143': [],
    'e_Fp143': [],
    'Fint143': [],
    'e_Fint143': [],
    'Fp151': [],
    'e_Fp151': [],
    'Fint151': [],
    'e_Fint151': [],
    'Fp158': [],
    'e_Fp158': [],
    'Fint158': [],
    'e_Fint158': [],
    'Fp166': [],
    'e_Fp166': [],
    'Fint166': [],
    'e_Fint166': [],
    'Fp174': [],
    'e_Fp174': [],
    'Fint174': [],
    'e_Fint174': [],
    'Fp181': [],
    'e_Fp181': [],
    'Fint181': [],
    'e_Fint181': [],
    'Fp189': [],
    'e_Fp189': [],
    'Fint189': [],
    'e_Fint189': [],
    'Fp197': [],
    'e_Fp197': [],
    'Fint197': [],
    'e_Fint197': [],
    'Fp204': [],
    'e_Fp204': [],
    'Fint204': [],
    'e_Fint204': [],
    'Fp212': [],
    'e_Fp212': [],
    'Fint212': [],
    'e_Fint212': [],
    'Fp220': [],
    'e_Fp220': [],
    'Fint220': [],
    'e_Fint220': [],
    'Fp227': [],
    'e_Fp227': [],
    'Fint227': [],
    'e_Fint227': []      }
    return data

# %%
for i, Dataname in enumerate(set(Xmatch.name[0:len(Xmatch.RA_hh)-1])): # enumerate(set(Xmatch.name[0:len(Xmatch.RA_hh)-1]))
    # set: find every name
    # enumerate: add index and list out the name
    
    print('i = ',i, ' source name =', Dataname)    
    df = ClearData()
    
    RAX_hh = Xmatch['RA_hh'][Xmatch['name'] == Dataname].values[0] # RA_hh which name is consist with "Dataname", than extract it value (.values[0])
    RAX_mm = Xmatch['RA_mm'][Xmatch['name'] == Dataname].values[0]
    RAX_ss = Xmatch['RA_ss'][Xmatch['name'] == Dataname].values[0]
    DECX_dd = Xmatch['DEC_dd'][Xmatch['name'] == Dataname].values[0]
    DECX_mm = Xmatch['DEC_mm'][Xmatch['name'] == Dataname].values[0]
    DECX_ss = Xmatch['DEC_ss'][Xmatch['name'] == Dataname].values[0]
    
    # combine Xmatch coordinates into a string array
    RA_X  = f'{RAX_hh} {RAX_mm} {RAX_ss}' # sort RA in to a string array (f'')
    DEC_X = f'{DECX_dd} {DECX_mm} {DECX_ss}' # sort RA in to a string array
    
    writeXmatch = True
    for j in range(2, len(GLEAM.RA_hh)-1): #range(2, 8): # range(2, len(VLASS.RA_hh)-1): *** MUST start from 2***
        
        RA_V  = f'{GLEAM.RA_hh[j]} {GLEAM.RA_mm[j]} {float(GLEAM.RA_ss[j])}'
        DEC_V = f'{GLEAM.DEC_dd[j]} {GLEAM.DEC_mm[j]} {float(GLEAM.DEC_ss[j])}'

        if (RA_X == RA_V):
            
            if writeXmatch: # if true
                
                ### in order to find the index of the same name
                Index = Xmatch[Xmatch['name'] == Dataname].index.tolist() # convert the index into a list 

                for x in Index: 
                    
                    df['Name'].append(Xmatch.name[x])
                    df['RA'].append(Xmatch.RA[x])
                    df['DEC'].append(Xmatch.DEC[x])
                    df['z'].append(Xmatch.z[x])
                    df['Rmag'].append(Xmatch.Rmag[x])
                    df['class'].append(Xmatch.Class[x])
                    df['band'].append(Xmatch.band[x])
                    df['freq'].append(Xmatch.freq[x])
                    df['date'].append(Xmatch.date[x])
                    df['flux_ratio'].append(Xmatch.flux_ratio[x])
                    df['flux_143'].append(Xmatch.flux_143[x])
                    df['flux_xray'].append(Xmatch.flux_xray[x])
                    df['flux_gamma'].append(Xmatch.flux_gamma[x])
                    df['Spec_index'].append(Xmatch.Spec_index[x]) 
                    df['flux_ALMA'].append(Xmatch.flux_ALMA[x])
                    df['errflux'].append(Xmatch.errflux[x])   
                    
                writeXmatch = False
                
            if not np.isnan(float(GLEAM.Fpwide[j])): # if Ftot is not NaN
               
                #print('have VLASS data')
                df['Fpwide'].append(float(GLEAM.Fpwide[j]))
                df['e_Fpwide'].append(float(GLEAM.e_Fpwide[j]))
                df['Fintwide'].append(float(GLEAM.Fintwide[j]))
                df['e_Fintwide'].append(float(GLEAM.e_Fintwide[j]))
                df['Fp076'].append(float(GLEAM.Fp076[j]))
                df['e_Fp076'].append(float(GLEAM.e_Fp076[j]))
                df['Fint076'].append(float(GLEAM.Fint076[j]))
                df['e_Fint076'].append(float(GLEAM.e_Fint076[j]))
                df['Fp084'].append(float(GLEAM.Fp084[j]))
                df['e_Fp084'].append(float(GLEAM.e_Fp084[j]))
                df['Fint084'].append(float(GLEAM.Fint084[j]))
                df['e_Fint084'].append(float(GLEAM.e_Fint084[j]))
                df['Fp092'].append(float(GLEAM.Fp092[j]))
                df['e_Fp092'].append(float(GLEAM.e_Fp092[j]))
                df['Fint092'].append(float(GLEAM.Fint092[j]))
                df['e_Fint092'].append(float(GLEAM.e_Fint092[j]))
                df['Fp099'].append(float(GLEAM.Fp099[j]))
                df['e_Fp099'].append(float(GLEAM.e_Fp099[j]))
                df['Fint099'].append(float(GLEAM.Fint099[j]))
                df['e_Fint099'].append(float(GLEAM.e_Fint099[j]))
                df['Fp107'].append(float(GLEAM.Fp107[j]))
                df['e_Fp107'].append(float(GLEAM.e_Fp107[j]))
                df['Fint107'].append(float(GLEAM.Fint107[j]))
                df['e_Fint107'].append(float(GLEAM.e_Fint107[j]))
                df['Fp115'].append(float(GLEAM.Fp115[j]))
                df['e_Fp115'].append(float(GLEAM.e_Fp115[j]))
                df['Fint115'].append(float(GLEAM.Fint115[j]))
                df['e_Fint115'].append(float(GLEAM.e_Fint115[j]))
                df['Fp122'].append(float(GLEAM.Fp122[j]))
                df['e_Fp122'].append(float(GLEAM.e_Fp122[j]))
                df['Fint122'].append(float(GLEAM.Fint122[j]))
                df['e_Fint122'].append(float(GLEAM.e_Fint122[j]))
                df['Fp130'].append(float(GLEAM.Fp130[j]))
                df['e_Fp130'].append(float(GLEAM.e_Fp130[j]))
                df['Fint130'].append(float(GLEAM.Fint130[j]))
                df['e_Fint130'].append(float(GLEAM.e_Fint130[j]))
                df['Fp143'].append(float(GLEAM.Fp143[j]))
                df['e_Fp143'].append(float(GLEAM.e_Fp143[j]))
                df['Fint143'].append(float(GLEAM.Fint143[j]))
                df['e_Fint143'].append(float(GLEAM.e_Fint143[j]))
                df['Fp151'].append(float(GLEAM.Fp151[j]))
                df['e_Fp151'].append(float(GLEAM.e_Fp151[j]))
                df['Fint151'].append(float(GLEAM.Fint151[j]))
                df['e_Fint151'].append(float(GLEAM.e_Fint151[j]))
                df['Fp158'].append(float(GLEAM.Fp158[j]))
                df['e_Fp158'].append(float(GLEAM.e_Fp158[j]))
                df['Fint158'].append(float(GLEAM.Fint158[j]))
                df['e_Fint158'].append(float(GLEAM.e_Fint158[j]))
                df['Fp166'].append(float(GLEAM.Fp166[j]))
                df['e_Fp166'].append(float(GLEAM.e_Fp166[j]))
                df['Fint166'].append(float(GLEAM.Fint166[j]))
                df['e_Fint166'].append(float(GLEAM.e_Fint166[j]))
                df['Fp174'].append(float(GLEAM.Fp174[j]))
                df['e_Fp174'].append(float(GLEAM.e_Fp174[j]))
                df['Fint174'].append(float(GLEAM.Fint174[j]))
                df['e_Fint174'].append(float(GLEAM.e_Fint174[j]))
                df['Fp181'].append(float(GLEAM.Fp181[j]))
                df['e_Fp181'].append(float(GLEAM.e_Fp181[j]))
                df['Fint181'].append(float(GLEAM.Fint181[j]))
                df['e_Fint181'].append(float(GLEAM.e_Fint181[j]))
                df['Fp189'].append(float(GLEAM.Fp189[j]))
                df['e_Fp189'].append(float(GLEAM.e_Fp189[j]))
                df['Fint189'].append(float(GLEAM.Fint189[j]))
                df['e_Fint189'].append(float(GLEAM.e_Fint189[j]))
                df['Fp197'].append(float(GLEAM.Fp197[j]))
                df['e_Fp197'].append(float(GLEAM.e_Fp197[j]))
                df['Fint197'].append(float(GLEAM.Fint197[j]))
                df['e_Fint197'].append(float(GLEAM.e_Fint197[j]))
                df['Fp204'].append(float(GLEAM.Fp204[j]))
                df['e_Fp204'].append(float(GLEAM.e_Fp204[j]))
                df['Fint204'].append(float(GLEAM.Fint204[j]))
                df['e_Fint204'].append(float(GLEAM.e_Fint204[j]))
                df['Fp212'].append(float(GLEAM.Fp212[j]))
                df['e_Fp212'].append(float(GLEAM.e_Fp212[j]))
                df['Fint212'].append(float(GLEAM.Fint212[j]))
                df['e_Fint212'].append(float(GLEAM.e_Fint212[j]))
                df['Fp220'].append(float(GLEAM.Fp220[j]))
                df['e_Fp220'].append(float(GLEAM.e_Fp220[j]))
                df['Fint220'].append(float(GLEAM.Fint220[j]))
                df['e_Fint220'].append(float(GLEAM.e_Fint220[j]))
                df['Fp227'].append(float(GLEAM.Fp227[j]))
                df['e_Fp227'].append(float(GLEAM.e_Fp227[j]))
                df['Fint227'].append(float(GLEAM.Fint227[j]))
                df['e_Fint227'].append(float(GLEAM.e_Fint227[j]))

                
                #print('VLASS size = ', len(df['Ftot']))
                
            else:
                
                #print('no VLASS data')
                df['Fpwide'].append(np.nan)
                df['e_Fpwide'].append(np.nan)
                df['Fintwide'].append(np.nan)
                df['e_Fintwide'].append(np.nan)
                df['Fp076'].append(np.nan)
                df['e_Fp076'].append(np.nan)
                df['Fint076'].append(np.nan)
                df['e_Fint076'].append(np.nan)
                df['Fp084'].append(np.nan)
                df['e_Fp084'].append(np.nan)
                df['Fint084'].append(np.nan)
                df['e_Fint084'].append(np.nan)
                df['Fp092'].append(np.nan)
                df['e_Fp092'].append(np.nan)
                df['Fint092'].append(np.nan)
                df['e_Fint092'].append(np.nan)
                df['Fp099'].append(np.nan)
                df['e_Fp099'].append(np.nan)
                df['Fint099'].append(np.nan)
                df['e_Fint099'].append(np.nan)
                df['Fp107'].append(np.nan)
                df['e_Fp107'].append(np.nan)
                df['Fint107'].append(np.nan)
                df['e_Fint107'].append(np.nan)
                df['Fp115'].append(np.nan)
                df['e_Fp115'].append(np.nan)
                df['Fint115'].append(np.nan)
                df['e_Fint115'].append(np.nan)
                df['Fp122'].append(np.nan)
                df['e_Fp122'].append(np.nan)
                df['Fint122'].append(np.nan)
                df['e_Fint122'].append(np.nan)
                df['Fp130'].append(np.nan)
                df['e_Fp130'].append(np.nan)
                df['Fint130'].append(np.nan)
                df['e_Fint130'].append(np.nan)
                df['Fp143'].append(np.nan)
                df['e_Fp143'].append(np.nan)
                df['Fint143'].append(np.nan)
                df['e_Fint143'].append(np.nan)
                df['Fp151'].append(np.nan)
                df['e_Fp151'].append(np.nan)
                df['Fint151'].append(np.nan)
                df['e_Fint151'].append(np.nan)
                df['Fp158'].append(np.nan)
                df['e_Fp158'].append(np.nan)
                df['Fint158'].append(np.nan)
                df['e_Fint158'].append(np.nan)
                df['Fp166'].append(np.nan)
                df['e_Fp166'].append(np.nan)
                df['Fint166'].append(np.nan)
                df['e_Fint166'].append(np.nan)
                df['Fp174'].append(np.nan)
                df['e_Fp174'].append(np.nan)
                df['Fint174'].append(np.nan)
                df['e_Fint174'].append(np.nan)
                df['Fp181'].append(np.nan)
                df['e_Fp181'].append(np.nan)
                df['Fint181'].append(np.nan)
                df['e_Fint181'].append(np.nan)
                df['Fp189'].append(np.nan)
                df['e_Fp189'].append(np.nan)
                df['Fint189'].append(np.nan)
                df['e_Fint189'].append(np.nan)
                df['Fp197'].append(np.nan)
                df['e_Fp197'].append(np.nan)
                df['Fint197'].append(np.nan)
                df['e_Fint197'].append(np.nan)
                df['Fp204'].append(np.nan)
                df['e_Fp204'].append(np.nan)
                df['Fint204'].append(np.nan)
                df['e_Fint204'].append(np.nan)
                df['Fp212'].append(np.nan)
                df['e_Fp212'].append(np.nan)
                df['Fint212'].append(np.nan)
                df['e_Fint212'].append(np.nan)
                df['Fp220'].append(np.nan)
                df['e_Fp220'].append(np.nan)
                df['Fint220'].append(np.nan)
                df['e_Fint220'].append(np.nan)
                df['Fp227'].append(np.nan)
                df['e_Fp227'].append(np.nan)
                df['Fint227'].append(np.nan)
                df['e_Fint227'].append(np.nan)
        else:
            
             if writeXmatch: # if true
                
                ### in order to find the index of the same name
                Index = Xmatch[Xmatch['name'] == Dataname].index.tolist() # convert the index into a list 

                for x in Index: 
                    
                    df['Name'].append(Xmatch.name[x])
                    df['RA'].append(Xmatch.RA[x])
                    df['DEC'].append(Xmatch.DEC[x])
                    df['z'].append(Xmatch.z[x])
                    df['Rmag'].append(Xmatch.Rmag[x])
                    df['class'].append(Xmatch.Class[x])
                    df['band'].append(Xmatch.band[x])
                    df['freq'].append(Xmatch.freq[x])
                    df['date'].append(Xmatch.date[x])
                    df['flux_ratio'].append(Xmatch.flux_ratio[x])
                    df['flux_143'].append(Xmatch.flux_143[x])
                    df['flux_xray'].append(Xmatch.flux_xray[x])
                    df['flux_gamma'].append(Xmatch.flux_gamma[x])
                    df['Spec_index'].append(Xmatch.Spec_index[x]) 
                    df['flux_ALMA'].append(Xmatch.flux_ALMA[x])
                    df['errflux'].append(Xmatch.errflux[x])   

                writeXmatch = False
                
    len_Xmatch = len(df['Name'])
    len_GLEAM  = len(df['Fpwide'])
    
    print('len_Xmatch = ', len_Xmatch, ' len_GLEAM = ', len_GLEAM)
    
    # Xmatch data number > GLEAM data number
    if len_Xmatch > len_GLEAM:
        
        difflen = len_Xmatch - len_GLEAM
        
        for ii in range(difflen):
            
            df['Fpwide'].append(np.nan)
            df['e_Fpwide'].append(np.nan)
            df['Fintwide'].append(np.nan)
            df['e_Fintwide'].append(np.nan)
            df['Fp076'].append(np.nan)
            df['e_Fp076'].append(np.nan)
            df['Fint076'].append(np.nan)
            df['e_Fint076'].append(np.nan)
            df['Fp084'].append(np.nan)
            df['e_Fp084'].append(np.nan)
            df['Fint084'].append(np.nan)
            df['e_Fint084'].append(np.nan)
            df['Fp092'].append(np.nan)
            df['e_Fp092'].append(np.nan)
            df['Fint092'].append(np.nan)
            df['e_Fint092'].append(np.nan)
            df['Fp099'].append(np.nan)
            df['e_Fp099'].append(np.nan)
            df['Fint099'].append(np.nan)
            df['e_Fint099'].append(np.nan)
            df['Fp107'].append(np.nan)
            df['e_Fp107'].append(np.nan)
            df['Fint107'].append(np.nan)
            df['e_Fint107'].append(np.nan)
            df['Fp115'].append(np.nan)
            df['e_Fp115'].append(np.nan)
            df['Fint115'].append(np.nan)
            df['e_Fint115'].append(np.nan)
            df['Fp122'].append(np.nan)
            df['e_Fp122'].append(np.nan)
            df['Fint122'].append(np.nan)
            df['e_Fint122'].append(np.nan)
            df['Fp130'].append(np.nan)
            df['e_Fp130'].append(np.nan)
            df['Fint130'].append(np.nan)
            df['e_Fint130'].append(np.nan)
            df['Fp143'].append(np.nan)
            df['e_Fp143'].append(np.nan)
            df['Fint143'].append(np.nan)
            df['e_Fint143'].append(np.nan) 
            df['Fp151'].append(np.nan)
            df['e_Fp151'].append(np.nan)
            df['Fint151'].append(np.nan)
            df['e_Fint151'].append(np.nan)
            df['Fp158'].append(np.nan)
            df['e_Fp158'].append(np.nan)
            df['Fint158'].append(np.nan)
            df['e_Fint158'].append(np.nan)
            df['Fp166'].append(np.nan)
            df['e_Fp166'].append(np.nan)
            df['Fint166'].append(np.nan)
            df['e_Fint166'].append(np.nan)
            df['Fp174'].append(np.nan)
            df['e_Fp174'].append(np.nan)
            df['Fint174'].append(np.nan)
            df['e_Fint174'].append(np.nan)
            df['Fp181'].append(np.nan)
            df['e_Fp181'].append(np.nan)
            df['Fint181'].append(np.nan)
            df['e_Fint181'].append(np.nan)
            df['Fp189'].append(np.nan)
            df['e_Fp189'].append(np.nan)
            df['Fint189'].append(np.nan)
            df['e_Fint189'].append(np.nan)
            df['Fp197'].append(np.nan)
            df['e_Fp197'].append(np.nan)
            df['Fint197'].append(np.nan)
            df['e_Fint197'].append(np.nan)
            df['Fp204'].append(np.nan)
            df['e_Fp204'].append(np.nan)
            df['Fint204'].append(np.nan)
            df['e_Fint204'].append(np.nan)
            df['Fp212'].append(np.nan)
            df['e_Fp212'].append(np.nan)
            df['Fint212'].append(np.nan)
            df['e_Fint212'].append(np.nan)
            df['Fp220'].append(np.nan)
            df['e_Fp220'].append(np.nan)
            df['Fint220'].append(np.nan)
            df['e_Fint220'].append(np.nan)
            df['Fp227'].append(np.nan)
            df['e_Fp227'].append(np.nan)
            df['Fint227'].append(np.nan)
            df['e_Fint227'].append(np.nan)
            
    # GLEAM data number > Xmatch data number
    elif len_Xmatch < len_GLEAM:
        
        difflen = abs(len_Xmatch - len_GLEAM)
        
        for ii in range(difflen):
            
            df['Name'].append(Xmatch.name[x])
            df['RA'].append(Xmatch.RA[x])
            df['DEC'].append(Xmatch.DEC[x])
            df['z'].append(Xmatch.z[x])
            df['Rmag'].append(Xmatch.Rmag[x])
            df['class'].append(Xmatch.Class[x])
            df['band'].append(np.nan)
            df['freq'].append(np.nan)
            df['date'].append(np.nan)
            df['flux_ratio'].append(np.nan)
            df['flux_143'].append(np.nan)
            df['flux_xray'].append(np.nan)
            df['flux_gamma'].append(np.nan)
            df['Spec_index'].append(np.nan)
            df['flux_ALMA'].append(np.nan)
            df['errflux'].append(np.nan)
            
    #print(pd.DataFrame(df))
    
    CSVfile = f'{SAVEpath}/{Dataname}.csv'    
    dff = pd.DataFrame(df)      
    dff.to_csv(CSVfile, index = False)
    
    print('================================================EOF================================================')

# %%
#######################################################################################################
## find sources which Have GLEAM data (2023/2/3 made)
#######################################################################################################
import pandas as pd
import numpy as np

Xmatch = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/BZCAT_Xmatch_ACC_csv.csv') # # = 37671
RAX_hh = Xmatch['RA_hh'].values
RAX_mm = Xmatch['RA_mm'].values
RAX_ss = Xmatch['RA_ss'].values
DECX_dd = Xmatch['DEC_dd'].values
DECX_mm = Xmatch['DEC_mm'].values
DECX_ss = Xmatch['DEC_ss'].values
    
GLEAM = pd.read_csv('/Users/87steven/Documents/ASIAA/Blazar SED code and data/data/GLEAM_csv.csv')  # # = 8499
RA_hh = GLEAM['RA_hh'].values
RA_mm = GLEAM['RA_mm'].values
RA_ss = GLEAM['RA_ss'].values
DEC_dd = GLEAM['DEC_dd'].values
DEC_mm = GLEAM['DEC_mm'].values
DEC_ss = GLEAM['DEC_ss'].values

coordinate_X = [None]*len(Xmatch['RA_hh'])
for i in range(0, len(Xmatch['RA_hh'])):
    coordinate_X[i] = f'{RAX_hh[i]} {RAX_mm[i]} {RAX_ss[i]} {DECX_dd[i]} {DECX_mm[i]} {DECX_ss[i]}'
    
coordinate = [None]*(len(GLEAM['RA_hh']))
for k in range(0, len(GLEAM['RA_hh'])-1):
    coordinate[k] = f'{RA_hh[k]} {RA_mm[k]} {RA_ss[k]} {DEC_dd[k]} {DEC_mm[k]} {DEC_ss[k]}' 
    
coordinate_X = list(set(coordinate_X))
coordinate = list(set(coordinate))

aa = []

for i in range(0, len(coordinate_X)):
    for k in range(0, len(coordinate)):
        if coordinate_X[i] == coordinate[k]:
            aa.append([i, k])
            
print(len(aa), 'of sources have matched sources with ACC and BZCAT')
print(len(coordinate_X)-len(aa), 'of sources NO matched sources with ACC and BZCAT')
# Out:
# 1011 of sources have matched sources with ACC and BZCAT
# 356 of sources NO matched sources with ACC and BZCAT
